# %% [markdown]
# # Bank Customer Churn — Data Overview
#
# This notebook provides an initial overview of the Bank Customer Churn dataset — its structure, data types, and column definitions — before any cleaning or analysis begins.

# %% [markdown]
# ## 1. Import Libraries

# %%
import pandas as pd
import numpy as np

pd.set_option("display.max_columns", None)
pd.set_option("display.width", None)

# %% [markdown]
# ## 2. Load the Dataset

# %%
df = pd.read_csv("../dataset/Bank_Churn.csv")
df.head(10)
# Out:
#    CustomerId   Surname  CreditScore Geography  Gender  Age  Tenure  \
# 0    15634602  Hargrave          619    France  Female   42       2
# 1    15647311      Hill          608     Spain  Female   41       1
# 2    15619304      Onio          502    France  Female   42       8
# 3    15701354      Boni          699    France  Female   39       1
# 4    15737888  Mitchell          850     Spain  Female   43       2
# 5    15574012       Chu          645     Spain    Male   44       8
# 6    15592531  Bartlett          822    France    Male   50       7
# 7    15656148    Obinna          376   Germany  Female   29       4
# 8    15792365        He          501    France    Male   44       4
# 9    15592389        H?          684    France    Male   27       2
#
#      Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# 0       0.00              1          1               1        101348.88
# 1   83807.86              1          0               1        112542.58
# ...

# %% [markdown]
# ## 3. Dataset Structure
#
# A quick look at row/column counts, data types, and non-null counts.

# %%
print(f"Rows: {df.shape[0]}, Columns: {df.shape[1]}")
df.info()
# Out:
# Rows: 10000, Columns: 13
# <class 'pandas.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CustomerId       10000 non-null  int64
#  1   Surname          10000 non-null  str
#  2   CreditScore      10000 non-null  int64
#  3   Geography        10000 non-null  str
#  4   Gender           10000 non-null  str
#  5   Age              10000 non-null  int64
#  6   Tenure           10000 non-null  int64
#  7   Balance          10000 non-null  float64
#  8   NumOfProducts    10000 non-null  int64
#  9   HasCrCard        10000 non-null  int64
#  10  IsActiveMember   10000 non-null  int64
#  11  EstimatedSalary  10000 non-null  float64
#  12  Exited           10000 non-null  int64
# dtypes: float64(2), int64(8), str(3)
# memory usage: 1015.8 KB

# %% [markdown]
# ## 5. Categorical Column Values
#
# Checking the unique values in `Geography` and `Gender` to confirm there's no inconsistent labeling (e.g. typos, mixed casing).

# %%
print("Geography:", df["Geography"].unique())
print("Gender:", df["Gender"].unique())
# Out:
# Geography: <StringArray>
# ['France', 'Spain', 'Germany']
# Length: 3, dtype: str
# Gender: <StringArray>
# ['Female', 'Male']
# Length: 2, dtype: str

# %% [markdown]
# ## 6. Summary Statistics
#
# Numerical overview of all quantitative columns — useful for spotting outliers or implausible values early.

# %%
df.describe()
# Out:
#          CustomerId   CreditScore           Age        Tenure        Balance  \
# count  1.000000e+04  10000.000000  10000.000000  10000.000000   10000.000000
# mean   1.569094e+07    650.528800     38.921800      5.012800   76485.889288
# std    7.193619e+04     96.653299     10.487806      2.892174   62397.405202
# min    1.556570e+07    350.000000     18.000000      0.000000       0.000000
# 25%    1.562853e+07    584.000000     32.000000      3.000000       0.000000
# 50%    1.569074e+07    652.000000     37.000000      5.000000   97198.540000
# 75%    1.575323e+07    718.000000     44.000000      7.000000  127644.240000
# max    1.581569e+07    850.000000     92.000000     10.000000  250898.090000
#
#        NumOfProducts    HasCrCard  IsActiveMember  EstimatedSalary  \
# count   10000.000000  10000.00000    10000.000000     10000.000000
# mean        1.530200      0.70550        0.515100    100090.239881
# std         0.581654      0.45584        0.499797     57510.492818
# ...

# %% [markdown]
# ## 7. Missing Values Check

# %%
df.isnull().sum()
# Out:
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %% [markdown]
# ## 8. Target Variable Distribution
#
# How balanced is churn (`Exited`) in this dataset?

# %%
df["Exited"].value_counts(normalize=True).rename("proportion")
# Out:
# Exited
# 0    0.7963
# 1    0.2037
# Name: proportion, dtype: float64
